# %%
# !uv add langchain
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from langchain_core.prompts import PromptTemplate
from typing import List, Dict

# %%
# Usage
news = """Apple Inc. reported quarterly earnings that beat Wall Street expectations, 
with revenue up 8% year-over-year driven by strong iPhone sales in emerging markets."""

# %%
class FinBERTSentimentAnalyzer:
    def __init__(self):
        """initialize FinBERT model"""
        model_name = "ProsusAI/finbert"
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.labels = ["positive", "negative", "neutral"]
    
    def analyze(self, news_text: str) -> Dict[str, any]:
        """Analyze sentiment with probabilities"""
        inputs = self.tokenizer(news_text, return_tensors="pt",
                                truncation=True, max_length=512)
        
        with torch.no_grad():
            outputs = self.model(**inputs)
            predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
        
        scores = predictions[0].tolist()
        sentiment_dict = {label: score for label, score in zip(self.labels, scores)}
        
        # Get primary sentiment
        primary_sentiment = self.labels[scores.index(max(scores))]
        confidence = max(scores)
        
        return {
            "sentiment": primary_sentiment,
            "confidence": confidence,
            "scores": sentiment_dict,
            "text": news_text
        }
    
    def batch_analyze(self, news_list: List[str]) -> List[Dict]:
        """Analyze multiple news items"""
        return [self.analyze(news) for news in news_list]

# %%
# Usage
news = """Apple Inc. reported quarterly earnings that beat Wall Street expectations, 
with revenue up 8% year-over-year driven by strong iPhone sales in emerging markets."""

analyzer = FinBERTSentimentAnalyzer()
result = analyzer.analyze(news)
print(f"Sentiment: {result['sentiment']}")
print(f"Confidence: {result['confidence']:.2%}")
print(f"All scores: {result['scores']}")

# %%
# from langchain_core.chains import LLMChain
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate

class HybridFinancialAnalyzer:
    def __init__(self):
        self.finbert = FinBERTSentimentAnalyzer()
        self.llm = OllamaLLM(model="minimax-m2:cloud", temperature=0.1)
        
        self.explanation_prompt = PromptTemplate(
            input_variables=["news_text", "sentiment", "confidence"],
            template="""The following financial news has been classified as {sentiment} with {confidence:.1%} confidence:

News: {news_text}

Provide a detailed analysis explaining:
1. Why this sentiment classification makes sense
2. Key financial indicators or events mentioned
3. Potential market implications
4. Any risks or uncertainties

Analysis:"""
        )
        
        # self.chain = LLMChain(llm=self.llm, prompt=self.explanation_prompt)
    
    def analyze(self, news_text: str) -> Dict:
        # Get quick sentiment from FinBERT
        print("Analyzing sentiment with FinBERT...")
        finbert_result = self.finbert.analyze(news_text)

        # Create the chain using the | operator (modern LangChain syntax)
        print("Generating detailed analysis with LLM...")
        chain = self.explanation_prompt | self.llm
        # Get detailed explanation from LLM
        explanation = chain.invoke({
            "news_text": news_text,
            "sentiment": finbert_result['sentiment'],
            "confidence": finbert_result['confidence']
        })
        print("Analysis complete!")
        return {
            **finbert_result,
            "detailed_analysis": explanation
        }
# print(result)

# %%
# Usage
hybrid_analyzer = HybridFinancialAnalyzer()
result = hybrid_analyzer.analyze(news)
print(f"Sentiment: {result['sentiment']}")
print(f"Confidence: {result['confidence']:.2%}")
print(f"All scores: {result['scores']}")
print(result['detailed_analysis'])
# Out:
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
# Sentiment: positive
# Confidence: 95.90%
# All scores: {'positive': 0.9590075612068176, 'negative': 0.02066086418926716, 'neutral': 0.020331567153334618}
# ## Analysis of Apple Earnings News Classification
#
# ### 1. Why This Sentiment Classification Makes Sense
#
# The 95.9% confidence positive classification is justified for several compelling reasons:
#
# **Fundamental Beat**: Apple "beat Wall Street expectations" represents a fundamental positive surprise for investors, as beating earnings estimates typically drives stock prices higher and signals company management is outperforming market consensus.
#
# **Growth Confirmation**: The 8% year-over-year revenue increase demonstrates continuous business growth, which is particularly important for a mature, large-cap company like Apple where investors often worry about growth deceleration.
#
# **Market Expansion**: Strong iPhone sales in "emerging markets" (likely referring to India, China, Southeast Asia, etc.) suggests Apple is successfully penetrating high-growth regions, offsetting potential saturation in mature markets.
#
# **Operational Excellence**: Strong iPhone sales typically represent higher-margin revenue, suggesting both volume and profit potential, creating a positive business momentum narrative.
#
# ### 2. Key Financial Indicators and Events
#
# **Primary Metric**: 8% year-over-year revenue growth
# - This is a healthy growth rate for a company of Apple's size and maturity
# - Compares favorably to typical tech sector growth expectations
#
# **Performance vs. Expectations**: Beat of Wall Street earnings expectations
# - Suggests management guidance may be conservative or operations outperforming projections
# - Likely led to earnings per share (EPS) beating consensus estimates
#
# **Geographic Success**: Strong iPhone sales in emerging markets
# - Indicates successful product localization and market penetration strategy
# - Potential for significant future growth as smartphone adoption increases in these regions
#
# ### 3. Potential Market Implications
#
# **Short-term Effects**:
# - Apple stock likely to experience positive price movement on news
# - Increased analyst target price upgrades and EPS estimate revisions
# - Potentially improved sentiment toward other tech mega-caps
#
# **Medium-term Benefits**:
# - Reinforces Apple's competitive position in global smartphone market
# - Could drive increased investor confidence in Apple's long-term growth story
# - May attract new institutional investors seeking growth with stability
#
# **Sector Impact**:
# - Positive sentiment could spill over to other consumer electronics and technology stocks
# - Strengthens the narrative for companies that can successfully operate in emerging markets
#
# **Valuation Considerations**:
# - Higher confidence in sustained growth could support premium valuation multiples
# - Potential for increased price-to-earnings ratios as growth sustainability is proven
#
# ### 4. Risks and Uncertainties
#
# **Market Saturation Concerns**:
# - Despite success in emerging markets, overall smartphone growth is slowing globally
# - Risk that emerging market growth may not fully offset mature market maturity
#
# **Competitive Pressure**:
# - Intensifying competition from Chinese smartphone manufacturers (Xiaomi, Huawei) and Samsung
# - Risk of price competition affecting margins in key markets
#
# **Currency and Economic Headwinds**:
# - Emerging markets often face currency volatility affecting local purchasing power
# - Potential for economic downturns in key emerging markets impacting demand
#
# **Product Innovation Dependency**:
# - Reliance on new iPhone models for continued growth success
# - Risk if future product iterations fail to generate similar demand patterns
#
# **Geopolitical Tensions**:
# - Potential impact on China trade relations and market access
# - Regulatory challenges in various markets affecting operational flexibility
#
# **Long-term Sustainability**:
# - 8% growth rate may not be maintainable indefinitely
# - Risk of growth rate normalization affecting valuation expectations
#
# This classification demonstrates strong positive sentiment based on concrete financial outperformance while acknowledging inherent market risks that could affect future performance.

# %%
# Complete workflow
news_retriever = NewsRetriever()
analyzer = HybridFinancialAnalyzer()

# Get news and analyze
news_items = news_retriever.get_financial_news()
for item in news_items:
    text = f"{item['title']}. {item['summary']}"
    sentiment = analyzer.analyze(text)
    print(f"\nNews: {item['title']}")
    print(f"Sentiment: {sentiment['sentiment']} ({sentiment['confidence']:.1%})")
    llm_result = analyzer.analyze(text)
    print(llm_result['detailed_analysis'])
# Out:
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
#
# News: Shutdown means another missed jobs report Friday. Here's what it probably would have shown
# Sentiment: negative (96.1%)
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
# **Analysis of Negative Sentiment Classification (96.1% Confidence)**
#
# ## 1. Why This Sentiment Classification Makes Sense
#
# The 96.1% negative confidence classification is highly justified because this news represents a significant institutional failure with multiple negative implications:
#
# - **Governance Disruption**: A "record-long government shutdown" signals systemic dysfunction in federal operations
# - **Information Asymmetry**: The absence of official jobs data creates a critical information void in financial markets
# - **Economic Monitoring Failure**: Jobs reports are among the most closely watched economic indicators; their absence hampers market participants' ability to assess economic health
# - **Precedent Setting**: Record duration suggests this is not a brief, manageable disruption but a substantial breakdown
#
# ## 2. Key Financial Indicators or Events Mentioned
#
# **Primary Event**:
# - **Government Shutdown** (record-long duration)
#
# **Missing Financial Indicator**:
# - **Monthly Jobs Report** (typically released on Fridays by Bureau of Labor Statistics)
#
# **Timing Context**:
# - **Friday** (scheduled release date)
# - **Weekly frequency** of job reporting cycles
# - **Official data void** affecting multiple stakeholders
#
# ## 3. Potential Market Implications
#
# **Short-term Effects**:
# - **Increased Market Volatility**: Lack of key data typically drives higher price swings as traders operate with incomplete information
# - **Reduced Market Confidence**: Institutional investors may become more cautious without critical economic monitoring
# - **Federal Reserve Policy Uncertainty**: Central bank decisions made without employment data face greater uncertainty
# - **Sector-Specific Impact**: Labor-sensitive sectors (consumer discretionary, retail) may experience additional volatility
#
# **Medium-term Consequences**:
# - **Data Quality Concerns**: When data resumes, it may be viewed with skepticism due to prolonged disruption
# - **Market Adaptation Costs**: Participants must develop alternative data sources or adjusted strategies
# - **Credit Market Effects**: Lenders may become more conservative without timely employment data
#
# ## 4. Risks and Uncertainties
#
# **Data and Analysis Risks**:
# - **Quantification Gap**: Cannot measure actual employment impact during shutdown period
# - **Private Data Reliability**: Alternative sources may provide incomplete or inconsistent information
# - **Timing Deception**: Missed reports create false impressions of economic stability or decline
#
# **Policy and Regulatory Uncertainties**:
# - **Fed Decision-Making**: Monetary policy crafted without current employment trends increases risk of inappropriate actions
# - **Budget and Appropriations**: No resolution timeframe creates ongoing operational uncertainty
# - **Institutional Credibility**: Extended shutdown damages confidence in federal statistical agencies
#
# **Market Structure Risks**:
# - **Information Market Efficiency**: Markets function sub-optimally when key data is unavailable
# - **Informed Trading Challenges**: Sophisticated participants may have unfair advantages with access to private indicators
# - **Regulatory Oversight**: Compliance and monitoring functions may be compromised without official data
#
# **Economic Assessment Limitations**:
# - **Trend Analysis Breaks**: Historical data comparisons become less reliable with extended gaps
# - **Seasonal Adjustment Issues**: Ongoing seasonal patterns cannot be properly monitored or adjusted
# - **Policy Response Timing**: Government and Fed responses may be delayed or miscalibrated due to data absence
#
# The high negative sentiment confidence reflects the multifaceted way this shutdown disrupts normal economic monitoring, policy-making, and market functioning - creating a compound risk scenario that affects virtually all aspects of financial market operations.
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
#
# News: Airlines cancel more than 700 U.S. flights as FAA-ordered shutdown cuts begin
# Sentiment: negative (96.9%)
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
# ## Analysis
#
# ### 1. Why This Sentiment Classification Makes Sense
#
# The negative sentiment classification at 96.9% confidence is highly justified because this news represents multiple interconnected economic disruptions that directly impact market confidence and business operations:
#
# - **Direct Revenue Impact**: Flight cancellations represent immediate revenue loss for airlines, with each canceled flight typically costing airlines thousands of dollars in lost ticket sales, fuel costs, and operational inefficiencies
# - **Systemic Infrastructure Risk**: Air traffic control disruption signals potential broader transportation system vulnerabilities, which can cascade into supply chain disruptions
# - **Government Functioning Risk**: The involvement of government workers missing paychecks indicates broader fiscal instability affecting multiple sectors
#
# ### 2. Key Financial Indicators or Events Mentioned
#
# **Quantitative Metrics:**
# - 700+ canceled flights (specific operational impact measurement)
# - Government shutdown duration: "longest in U.S. history" (unprecedented scale indicator)
#
# **Structural Elements:**
# - Air traffic controllers as essential federal workers
# - FAA operational authority over flight safety
# - Government shutdown's historical precedent-setting nature
# - Worker compensation disruption affecting critical infrastructure personnel
#
# ### 3. Potential Market Implications
#
# **Aviation Sector Impact:**
# - **Immediate**: Airlines should expect reduced Q4/Q1 earnings, potential earnings guidance revisions, and stock price volatility
# - **Short-term**: Consumer confidence in air travel may decline, leading to potential booking cancellations and reduced demand
# - **Competitive Dynamics**: Larger airlines with better cash reserves may weather the disruption better than regional carriers
#
# **Broader Economic Effects:**
# - **Supply Chain**: Potential delays in air cargo operations affecting just-in-time manufacturing and retail inventory
# - **Tourism**: Reduced confidence in travel reliability could impact hospitality, leisure, and destination-based businesses
# - **Federal Workforce Spending**: Missed paychecks reduce consumer spending in affected regions, potentially creating local economic ripples
#
# **Financial Markets:**
# - **Bond Markets**: Increased uncertainty about government functionality may impact treasury yields and government confidence metrics
# - **Equity Markets**: Sector rotation away from transportation and government-dependent industries toward more defensive sectors
#
# ### 4. Risks or Uncertainties
#
# **Temporal Uncertainty:**
# - **Duration Risk**: No clear endpoint for the shutdown creates planning challenges for airlines in workforce scheduling and route planning
# - **Recurrence Risk**: Potential for similar shutdowns in the future creates ongoing operational uncertainty
#
# **Operational Cascading Effects:**
# - **Safety Protocol Risk**: Understaffed air traffic control may need to implement safety measures that could further reduce flight capacity
# - **Worker Attrition**: Essential workers facing financial hardship may consider career changes, creating long-term staffing challenges
#
# **Economic Interconnectedness:**
# - **Multi-Sector Impact**: Government shutdowns typically affect multiple industries simultaneously, creating compound financial stress
# - **Consumer Behavior Changes**: Travel hesitancy may persist beyond the immediate crisis, creating longer-term demand destruction
#
# **Policy and Political Risk:**
# - **Regulatory Response**: Potential for emergency legislation or regulatory changes that could alter operational requirements
# - **International Relations**: U.S. flight restrictions may affect international aviation agreements and competitive positioning
#
# **Financial Stability Concerns:**
# - **Airline Credit Risk**: Reduced cash flow may stress airline balance sheets, particularly for carriers with high debt loads
# - **Insurance Implications**: Potential for increased premiums or coverage changes related to government-related operational disruptions
#
# This classification reflects the immediate operational disruption, the precedent-setting nature of the longest shutdown in U.S. history, and the potential for significant economic multiplier effects across multiple sectors of the economy.
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
#
# News: Google's decade-long bet on custom chips is turning into company's secret weapon in AI race
# Sentiment: neutral (86.4%)
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
# ### 1) Why this sentiment classification makes sense
# - Neutral tone with no strong bullish or bearish language: the headline is factual, and the article focuses on strategic positioning rather than promises or warnings.
# - Descriptive, comparative framing: the piece contrasts TPU capabilities with general cloud/gpu dynamics, so it doesn’t champion or condemn.
# - No explicit financial outlook or guidance: there’s no mention of revenue targets, margin targets, or model accuracy breakthroughs, so the model defaults to neutral.
# - Reliability and scale are described without hype: terms like “secret weapon” are used idiomatically, not as quantitative claims, and the piece is anchored to actual product names (Tensor Processing Units) and established business lines (Google Cloud).
#
# ### 2) Key financial indicators or events mentioned
# - Google’s custom chips (Tensor Processing Units) are a long-term bet, now material to the AI race.
# - Google Cloud is a primary growth engine, with custom chips helping drive Cloud’s performance and efficiency.
#
# Table: What’s measured and why it matters
# | Item | Why it matters (1–2 lines) |
# |---|---|
# | Google Cloud growth as a growth engine | Signals a shift from primarily ad-led growth to cloud-led growth; cloud tends to have higher recurring revenue and can diversify earnings. |
# | TPU investment timeline (decade-long bet) | Suggests amortization over a long horizon, with earlier capex now potentially compounding into lower costs/lead times. |
# | Custom silicon strategy | Directs capital toward differentiated compute and potentially improves price–performance vs. generic GPUs, which can lift margins. |
# | Compute efficiency and AI workloads | Efficiency gains in training/serving models can cut unit costs, reduce energy spend, and improve throughput on the same rack-space. |
# | Potential for cost/performance improvements | Better price–performance makes cloud offers more attractive, supporting Cloud revenue growth and share. |
#
# ### 3) Potential market implications
# - Google Cloud’s competitiveness and share could improve, especially in enterprise AI and workload consolidation.
# - TPU differentiation may compress costs and reduce reliance on third-party chips, strengthening gross margins over time.
# - Investors may value the platform more positively if this translates into sustained Cloud growth and unit-economy gains.
# - Supplier dynamics could change if Google rebalances away from third-party GPUs for specific workloads.
#
# Table: What it could mean for the market
# | Outcome | What it could mean |
# |---|---|
# | More AI workload migration to Google Cloud | Enterprises choose Google for tuned hardware and integrated AI stack; like choosing a fast commuter train over a taxi during rush hour. |
# | Lower compute unit costs | With more efficient chips, Google can price competitive offerings and still protect margins; like getting better gas mileage for the same driving needs. |
# | Potential margin tailwinds | Efficient use of data center CAPEX and power reduces cost per model-inference, supporting margin improvement. |
# | Competitive parity with hyperscalers | As TPUs and optimization improve, Google’s AI offering can rival AWS and Azure more directly. |
# | Broader ecosystem of AI services | Stronger compute back end may feed enterprise apps, analytics, and content services, deepening customer lock-in. |
#
# ### 4) Risks or uncertainties
# - Execution and scale: TPU systems must keep pace with rapid model growth, ecosystem integration, and security/compliance needs.
# - Uptime and energy costs: Data center uptime and power costs can swing economics; like a long car trip where gas prices change daily.
# - Competitive catch-up: Other hyperscalers are also investing heavily in custom chips and optimization; advantage may narrow.
# - Regulatory and AI governance: Evolving rules on AI safety and data handling may constrain deployments or require significant changes.
#
# Table: Key risks and why they matter
# | Risk | Why it matters |
# |---|---|
# | Model complexity and scaling | As models grow, chip interoperability and software stack maturity can limit cost/performance gains. |
# | Data center power and cooling | High power density and cooling can raise costs, delay deployments, and introduce reliability risks. |
# | Ecosystem and software tools | Success depends on developer adoption and smooth integration with existing enterprise tools. |
# | Regulatory AI risk | Compliance and governance can slow rollout, add costs, or limit certain use-cases. |
# | Economic cyclicality | Demand for AI compute is sensitive to macro conditions; a slowdown could delay projects. |
# | Supplier relations | Rebalancing chip procurement can affect partner relationships and strategic flexibility. |
# | Pricing and gross margin | Cloud pricing pressure may cap margin gains even with better efficiency. |
#
# Practical take: The report is neutral because it’s a factual strategic update. It points to a strong lever—custom silicon—that could help Cloud’s growth and economics. The upside is real, but execution, power constraints, and the pace of competition will determine how much the “secret weapon” really benefits the P&L.
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
#
# News: Tesla says shareholders approve Musk's $1 trillion pay plan with over 75% voting in favor
# Sentiment: positive (86.5%)
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
# # Analysis of the “Positive” Classification
#
# ## Why the sentiment classification makes sense
# The news is framed as positive because it signals that shareholders have given an overwhelming vote of confidence in Musk and the company’s strategy, and the pay structure is designed to reward him only if Tesla delivers exceptional, long-term value. A 75% approval rate is well above the typical 50% + 1 threshold for such decisions, indicating broad support from both retail and institutional shareholders. The wording “historic” and “over 75% voting in favor” amplifies perceived momentum and market alignment. In this context, classification engines tend to classify the passage as positive, especially when historical news on similar pay approvals has coincided with positive stock reactions.
#
# ## Key financial indicators or events mentioned
# - The pay plan is framed as “historic” and is widely described in magnitude terms (often reported as potentially up to $1 trillion if every tranche vests at the upper end and the stock appreciates significantly).
# - More than 75% of shareholders voted in favor, suggesting strong alignment with the company’s long-term targets.
# - Key targets in the plan focus on sustained, ambitious milestones such as:
#   - Market capitalization growth (toward $650 billion),
#   - Revenue and operating profit goals,
#   - Capacity and vehicle sales ramp (e.g., annualized deliveries of 20 million vehicles),
#   - Further advances in autonomy/robotics and energy systems.
# - The structure is “all-in” equity with a decade-long horizon, prioritizing long-term performance over short-term cash awards.
# - Austin, Texas, is highlighted as the location of the annual meeting, which is relevant for signaling growth in Texas and broader US operations.
#
# ## Potential market implications
# - Near-term sentiment and trading: The approval and the high vote share could buoy short-term enthusiasm. Some investors may buy the news and expectations of continued high growth, while others could take profits into strength, especially if the stock has already run up this year.
# - Long-term alignment: The plan’s milestone-based structure can be viewed as a powerful alignment tool: Musk benefits only if Tesla consistently hits ambitious growth, efficiency, and market goals. This can improve investor confidence in execution over the next decade.
# - Governance signaling: The strong vote suggests a willingness among shareholders to back aggressive, transformative strategies. This could set expectations for bold future initiatives (robotaxis, robotics, AI, energy).
# - Costs and dilution: The 2018 pay plan, if decertified as some shareholders and legal observers have discussed, is expected to have required significant equity issuance. Similar new tranches would introduce dilution, which may depress EPS and warrant some multiple compression. The net effect will depend on how much value creation accompanies the dilution.
# - Capital allocation and valuation: Continued focus on capacity, AI/robotics, and energy storage could shape capital decisions. Strong execution could justify a higher multiple; missed targets could lead to a re-rating.
# - Sector benchmarking: An “all-in” pay plan with milestone tranches may push peers to reconsider compensation structures to attract visionary leadership, raising the bar for governance and performance expectations.
# - Information signaling: The headlines and vote percentage may become a narrative vector in sell-side notes, credit ratings, and proxy advisory commentary, which can affect sentiment and liquidity.
#
# ## Risks or uncertainties
# - Legal/regulatory risks:
#   - Decertification or court challenges to the 2018 plan are possible and could create headline risk or cost. Outcome uncertainty can weigh on governance perception and may add legal and administrative friction.
#   - Regulatory scrutiny of CEO pay, including proposed or new rules on board oversight, dilution disclosures, and clawbacks, could alter governance expectations and compliance costs.
# - Over-concentration and governance concerns:
#   - Concentrated decision-making with a single leader is high-conviction but can magnify risk. If leadership is distracted by other interests, delivery on ambitious milestones may be less reliable.
#   - The plan’s long time horizon and all-equity nature reduce short-term cash risk but make valuation highly path-dependent and sensitive to macroeconomic conditions.
# - Market concentration and mispricing:
#   - A large payoff tied primarily to share price growth risks reinforcing momentum cycles. If sentiment turns, the same mechanisms can amplify drawdowns.
#   - Potential policy or macro shocks (rates, consumer demand, geopolitical risk) could make the milestones harder to reach, impacting both performance and the perceived fairness of the pay.
# - Execution risk:
#   - The required scale and integration across vehicles, energy, AI/robotics, and autonomy is complex. Delivery delays or quality issues could harm stock sentiment and alter vesting prospects.
# - Dilution and value transfer:
#   - If equity grants outpace value creation, shareholders could feel a transfer of wealth. A detailed impact on EPS, free cash flow, and valuation multiples will be watched closely.
# - Narrative volatility:
#   - Reporting and public perception vary widely on the pay plan’s magnitude. Misinterpretation or inconsistent disclosures can drive short-term market noise and volatility.
#
# In summary, the positive classification aligns with broad shareholder endorsement, long-term alignment, and the framing of an ambitious plan. At the same time, investors should weigh governance, legal, execution, and dilution risks against the potential upside and sustained growth narrative.
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
#
# News: MP Materials CEO warns investors to approach suddenly hot rare earths industry with caution
# Sentiment: negative (58.9%)
# Analyzing sentiment with FinBERT...
# Generating detailed analysis with LLM...
# Analysis complete!
# ## Analysis of MP Materials CEO Warning
#
# ### 1. Why This Sentiment Classification Makes Sense
#
# The negative sentiment classification with 58.9% confidence is justified because:
#
# - **Direct cautionary language**: The CEO explicitly warns investors not to "get burned," using defensive and risk-averse terminology
# - **Economic concerns highlighted**: The emphasis on "difficult economics" signals underlying profitability challenges
# - **Market timing warning**: The reference to the industry being "suddenly hot" suggests a potential bubble or unsustainable demand surge
# - **Defensive positioning**: The CEO's protective tone suggests he's managing expectations and potential investor disappointment
#
# The 58.9% confidence score is moderate for negative sentiment, likely reflecting that while the message is negative, it's framed constructively (caution rather than panic) and comes from a company insider who benefits from the industry succeeding.
#
# ### 2. Key Financial Indicators or Events Mentioned
#
# **Explicit Indicators:**
# - Industry economics are described as "difficult"
# - "Sudden heat" in rare earths suggests rapid demand surge or speculation
# - Potential for investor losses ("getting burned")
#
# **Implicit Indicators:**
# - MP Materials' internal assessment that the industry's growth may not be sustainable
# - Recognition of valuation risks in the sector
# - Market volatility concerns despite current enthusiasm
#
# ### 3. Potential Market Implications
#
# **Short-term Impact:**
# - **Increased volatility** in rare earth mining and processing stocks
# - **Reassessment of valuations** across the rare earths sector
# - **More cautious investor behavior** when evaluating rare earth investments
# - **Potential profit-taking** in highly-valued rare earth companies
#
# **Long-term Impact:**
# - **More realistic market expectations** for rare earth industry returns
# - **Selective investment approach** - capital may flow to companies with stronger balance sheets and proven economics
# - **Industry consolidation** as weaker players struggle with difficult economics
# - **Enhanced due diligence** requirements for rare earth investments
#
# ### 4. Any Risks or Uncertainties
#
# **Industry-Specific Risks:**
# - **Commodity price volatility** - rare earths are subject to price fluctuations based on global supply/demand
# - **China dependency** - concerns about reliance on Chinese processing capabilities
# - **Environmental regulations** - potential costs and restrictions on mining operations
# - **Technology substitution** - threat of alternatives to rare earth materials
#
# **Market Timing Risks:**
# - **"Hot" industry cycles** - potential for bubble formation and subsequent crash
# - **Capital allocation misjudgments** - investors may over-allocate to the sector
# - **Commodity supercycle uncertainty** - unclear if this is sustainable growth or temporary
#
# **Company-Specific Risks:**
# - **MP Materials' competitive position** - whether they can navigate difficult economics better than competitors
# - **Execution risk** - turning challenging economics into profitable operations
# - **Strategic positioning** - ability to weather industry downturns
#
# The CEO's warning suggests recognizing these risks before they materialize, positioning MP Materials as more conservative in its growth expectations compared to market sentiment.

# %%
from newsdataapi import NewsDataApiClient
api = NewsDataApiClient(apikey='pub_965468a202be412d80928d294b632639')

# %%
all_articles = []
max_articles = 500
# for i in range(100):
response = api.news_api(q='stock market India economy finance',
                        category='business',
                        country='in',
                        language='en',
                        max_result=1)
# Out:
# C:\Users\krishnadas\AppData\Local\Temp\ipykernel_25120\1739721264.py:4: DeprecationWarning: This method is deprecated and will be removed in upcoming updates, Instead use latest_api()
#   response = api.news_api(q='stock market India economy finance',

# %%
response.get('results',[])
# Out:
# [{'article_id': '3ff8df26b83c247be5d18a6e75f45b7b',
#   'link': 'https://www.thehindubusinessline.com/portfolio/big-story/nifty-50-sensex-mr-perma-bull-takes-some-market-lessons-from-mr-doom/article70257284.ece',
#   'title': 'Nifty 50, Sensex: Mr Perma Bull takes some market lessons from Mr Doom',
#   'description': 'What is holding back markets? Two fictitious characters — Perma Bull, a long-term investor in Indian markets and a die-hard optimist, and Doom, a fundamental analyst — discuss the stock market performance',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': ['big story'],
#   'creator': ['Hari Viswanath'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['business'],
#   'pubDate': '2025-11-08 17:38:22',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://bl-i.thgim.com/public/incoming/vi1xwv/article70256968.ece/alternates/LANDSCAPE_1200/PO09_bull%20n%20bear.jpg',
#   'video_url': None,
#   'source_id': 'thehindubusinessline',
#   'source_name': 'The Hindu - Business Line',
#   'source_priority': 33540,
#   'source_url': 'https://www.thehindubusinessline.com',
#   'source_icon': 'https://n.bytvi.com/thehindubusinessline.png',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False},
#  {'article_id': '7bb273e1fbcfc221d985430e426f0216',
#   'link': 'https://www.thehindubusinessline.com/portfolio/personal-finance/business-cycle-funds-hit-or-miss/article70253910.ece',
#   'title': 'Business cycle funds: Hit or miss?',
#   'description': 'Not all business cycle funds succeed in reading the economic cycle accurately',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': ['personal finance'],
#   'creator': ['Dhuraivel Gunasekaran'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['business'],
#   'pubDate': '2025-11-08 16:16:19',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://bl-i.thgim.com/public/incoming/ch9ru4/article70256794.ece/alternates/LANDSCAPE_1200/PO09_Abstract_light.jpg',
#   'video_url': None,
#   'source_id': 'thehindubusinessline',
#   'source_name': 'The Hindu - Business Line',
#   'source_priority': 33540,
#   'source_url': 'https://www.thehindubusinessline.com',
#   'source_icon': 'https://n.bytvi.com/thehindubusinessline.png',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False},
#  {'article_id': 'af00868ff510802b37dee1a286cda202',
#   'link': 'https://www.latestly.com/agency-news/business-news-bajaj-finserv-banking-and-financial-services-fund-nfo-coming-soon-7196745.html',
#   'title': 'Business News | Bajaj Finserv Banking and Financial Services Fund NFO Coming Soon',
#   'description': "Get latest articles and stories on Business at LatestLY. Pune (Maharashtra) [India], November 8: India's financial sector has been evolving in tandem with the country's economic progress. The focus has been on strengthening financial intermediation, expanding inclusion, and advancing digital transformation.",
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': None,
#   'creator': ['ANI'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['top', 'business'],
#   'pubDate': '2025-11-08 06:52:26',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://st1.latestly.com/wp-content/uploads/2020/10/news-default-img-380x214.jpg',
#   'video_url': None,
#   'source_id': 'latestly',
#   'source_name': 'Latestly',
#   'source_priority': 31923,
#   'source_url': 'https://www.latestly.com',
#   'source_icon': 'https://n.bytvi.com/latestly.png',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False},
#  {'article_id': '280901da3cd2720b379d9c707c86ade8',
#   'link': 'https://www.theweek.in/wire-updates/business/2025/11/08/dcm10-bajaj-finserv-asset-management-ltd..html',
#   'title': 'Bajaj Finserv Banking and Financial Services Fund NFO Coming Soon',
#   'description': 'Pune, Maharashtra, India (NewsVoir) India’s financial sector has been evolving in tandem with the country’s economic progress. The focus has',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': None,
#   'creator': ['PTI'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['business'],
#   'pubDate': '2025-11-08 06:49:07',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://www.theweek.in/content/dam/week/wire-updates/pti-preview-theweek.jpg',
#   'video_url': None,
#   'source_id': 'theweek_in',
#   'source_name': 'The Week',
#   'source_priority': 693334,
#   'source_url': 'https://www.theweek.in',
#   'source_icon': 'https://n.bytvi.com/theweek_in.jpg',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': True},
#  {'article_id': '47315d9e11fecbbb382965aa9a57779c',
#   'link': 'https://www.dtnext.in/edit/editorial-big-banks-bigger-questions-852324',
#   'title': 'Editorial: Big banks, bigger questions',
#   'description': 'The NDA government claims to have implemented 86 major reforms in the banking sector and formulated a 4R policy: Recognize, Recover, Recapitalize, and Reform.',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': ['edit & opinions'],
#   'creator': ['Editorial'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['top', 'business'],
#   'pubDate': '2025-11-08 01:20:48',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://media.dtnext.in/h-upload/2025/05/29/750x450_865580-untitled.jpg',
#   'video_url': None,
#   'source_id': 'dtnext',
#   'source_name': 'Dt Next',
#   'source_priority': 113678,
#   'source_url': 'https://www.dtnext.in',
#   'source_icon': 'https://n.bytvi.com/dtnext.png',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False},
#  {'article_id': '363fb8a9947ede9c2c2c11191ff16751',
#   'link': 'https://www.devdiscourse.com/article/science-environment/3689811-bajaj-finserv-banking-and-financial-services-fund-nfo-coming-soon',
#   'title': 'Bajaj Finserv Banking and Financial Services Fund NFO Coming Soon',
#   'description': 'Indias financial sector has been evolving in tandem with the countrys economic progress The focus has been on strengthening financial intermediation expanding inclusion and advancing digital transformation',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': ['conclusion india’s',
#    'bfsi',
#    'un population\ndivision',
#    'world bank',
#    'the bajaj\nfinserv banking and financial services fund',
#    'nifty',
#    'pib',
#    'india',
#    'union ministry of\nrailways',
#    'financial services fund',
#    'bloomberg',
#    'mofsl',
#    'indian',
#    'the bajaj finserv banking and financial services fund new fund offer',
#    'broad'],
#   'creator': ['PTI'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['top', 'business'],
#   'pubDate': '2025-11-08 01:08:58',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://devdiscourse.blob.core.windows.net/imagegallery/27_06_2019_18_46_53_9831308.png',
#   'video_url': None,
#   'source_id': 'devdiscourse',
#   'source_name': 'Devdiscourse',
#   'source_priority': 566021,
#   'source_url': 'https://www.devdiscourse.com',
#   'source_icon': 'https://n.bytvi.com/devdiscourse.jpg',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False},
#  {'article_id': '603ace42cabb5ef2c307abeb94b64a4c',
#   'link': 'https://inc42.com/features/family-office-tracker-whos-betting-big-on-indias-next-unicorns/',
#   'title': 'Family Office Tracker: Here’s The List Of 200+ Investors Betting Big On Startups',
#   'description': 'Over the past decade, the Indian startup ecosystem has undergone a remarkable transformation. With over $150 Bn in funding raised...',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': ['follow up', 'in-depth'],
#   'creator': ['Lokesh Choudhary'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['top', 'business'],
#   'pubDate': '2025-11-07 11:25:43',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://inc42.com/cdn-cgi/image/quality=75/https://asset.inc42.com/2025/01/Family-Offices-ftr-4.jpg',
#   'video_url': None,
#   'source_id': 'inc42',
#   'source_name': 'Inc42',
#   'source_priority': 33695,
#   'source_url': 'https://inc42.com',
#   'source_icon': 'https://n.bytvi.com/inc42.png',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False},
#  {'article_id': '6aade6c39221171f1f63ab64124a7a7a',
#   'link': 'https://www.latestly.com/agency-news/business-news-sy-holdings-invited-to-attend-2025-hong-kong-fintech-week-leveraging-ai-to-boost-the-development-and-global-expansion-of-smes-7195890.html',
#   'title': 'Business News | SY Holdings Invited to Attend 2025 Hong Kong FinTech Week, Leveraging AI to Boost the Development and Global Expansion of SMEs',
#   'description': 'Get latest articles and stories on Business at LatestLY. Hong Kong, November 7: From November 3 to 4, 2025, "Hong Kong FinTech Week x StartmeupHK Festival 2025" (hereinafter referred to as "Hong Kong FinTech Week") was grandly held at the Hong Kong Convention and Exhibition Centre. The event is organized by the Hong Kong Financial Services and the Treasury Bureau, the Hong Kong Commerce and Economic Development Bureau, and Invest Hong Kong, in collaboration with the Hong Kong Monetary Authority, the Securities and Futures Commission, and the Insurance Authority. The opening ceremony was attended by several officials, including John KC Lee, Chief Executive of the Hong Kong Special Administrative Region, Christopher Hui, Secretary for Financial Services and the Treasury, and Eddie Yue, Chief Executive of the Hong Kong Monetary Authority.',
#   'content': 'ONLY AVAILABLE IN PAID PLANS',
#   'keywords': None,
#   'creator': ['ANI'],
#   'language': 'english',
#   'country': ['india'],
#   'category': ['top', 'business'],
#   'pubDate': '2025-11-07 11:20:28',
#   'pubDateTZ': 'UTC',
#   'image_url': 'https://st1.latestly.com/wp-content/uploads/2025/11/ANI-20251107110644.jpg',
#   'video_url': None,
#   'source_id': 'latestly',
#   'source_name': 'Latestly',
#   'source_priority': 31923,
#   'source_url': 'https://www.latestly.com',
#   'source_icon': 'https://n.bytvi.com/latestly.png',
#   'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#   'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#   'ai_summary': 'ONLY AVAILABLE IN PAID PLANS',
#   'duplicate': False}]

# %% [markdown]
# ### Using Mediastack

# %%
import requests
api_key = 'ad0657133e24010278b9e52debe35356'
base_url = 'https://api.mediastack.com/v1/news'

params = {
    'access_key': api_key,
    'countries': 'in',
    'categories': 'business',
    'keywords': 'market stock rupee economy',
    'limit': 100
}
response = requests.get(base_url, params=params)

# %%
response.json().get('data', [])
# Out:
# []

# %%
import http.client, urllib.parse

conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': 'ad0657133e24010278b9e52debe35356',
    'categories': 'business',
    'countries': 'in',
    'keywords': 'market stock rupee economy',
    'limit': 10,
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"pagination":{"limit":10,"offset":0,"count":0,"total":0},"data":[]}

# %%
import requests

# Use HTTP (not HTTPS) for free tier
url = 'http://api.mediastack.com/v1/news'

params = {
    'access_key': 'ad0657133e24010278b9e52debe35356',
    'countries': 'in',  # India
    'languages': 'en',
    'categories': 'business',  # Just business, don't use negatives
    'sort': 'published_desc',
    'limit': 100
}

response = requests.get(url, params=params)
data = response.json()

# %%
data['data'][8]
# Out:
# {'author': None,
#  'title': 'Lenskart IPO Allotment LIVE: GMP falls; Know step-by-step guide to check share allotment status online - livemint.com',
#  'description': "Lenskart IPO Allotment LIVE: GMP falls; Know step-by-step guide to check share allotment status online&nbsp;&nbsp;livemint.comLenskart IPO GMP falls sharply before listing. Is it heading for a weak debut?&nbsp;&nbsp;India TodaySoha Ali Khan simplifies stock market buzz around Lenskart’s Rs 7278 crore IPO, 'If you’re hoping to get&nbsp;&nbsp;Times of IndiaLIVE: Lenskart IPO allotment to be finalised, GMP up 10% – Step-by-step guide to check status online&nbsp;&nbsp;financialexpress.comLenskart IPO Allotment Live Updates: How to check status online on MUFG Intime India, BSE, NSE&nbsp;&nbsp;...",
#  'url': 'https://news.google....?oc=5',
#  'source': 'Google News Business IN',
#  'image': None,
#  'category': 'business',
#  'language': 'en',
#  'country': 'in',
#  'published_at': '2025-11-06T14:08:29+00:00'}

# %%
# Check if successful
if 'data' in data:
    articles = data['data']
    print(f"Found {len(articles)} articles\n")
    
    for i, article in enumerate(articles[:5], 1):
        print(f"{i}. {article['title']}")
        print(f"   Source: {article['source']}")
        print(f"   Published: {article['published_at']}\n")
else:
    print("Error:", data)
# Out:
# Found 100 articles
#
# 1. Should a few public sector banks be merged with State Bank of India (SBI) to create a big, world-class bank? - BusinessLine
#    Source: Google News Business IN
#    Published: 2025-11-07T20:56:05+00:00
#
# 2. Stock Market LIVE Updates: Sensex, Nifty trade flat as metals pack outshines - Moneycontrol
#    Source: Google News Business IN
#    Published: 2025-11-07T09:08:18+00:00
#
# 3. Stock Market LIVE: Sensex drops 510 pts; Talking to stakeholders on MF charges, says Sebi chairman - Business Standard
#    Source: Google News Business IN
#    Published: 2025-11-07T05:21:00+00:00
#
# 4. Stock Market LIVE: Sensex drops 560 pts; Talking to stakeholders on MF charges, says Sebi chairman - Business Standard
#    Source: Google News Business IN
#    Published: 2025-11-07T05:11:51+00:00
#
# 5. SBI, French partner Amundi to divest 10% in SBI Funds via IPO
#    Source: The Economic Times
#    Published: 2025-11-07T01:30:51+00:00

# %% [markdown]
# ### Newsdata.io and newspaper3k

# %%
from newspaper import Article
from newsdataapi import NewsDataApiClient
api = NewsDataApiClient(apikey='pub_965468a202be412d80928d294b632639')
# step 1: get articles from API
response = api.latest_api(
    q='stock market India economy finance',
    country='in',
    category='business',
    max_result=10
)
articles = response.get('results',[])

# %%
full_articles = []

# step 2: scrape full content from each URL
for idx, article in enumerate(articles, 1):
    try:
        print(f"Processing {idx}/{len(articles)}: {article['title'][:50]}...")

        # get full content
        news_article = Article(article['link'])
        news_article.download()
        news_article.parse()
        full_articles.append({
            'title': article['title'],
            'description': article['description'],
            'source': article['source_name'],
            'url': article['link'],
            'pubDate': article['pubDate'],
            'category': article['category'],
            'full_content': news_article.text,
            'authors': ', '.join(news_article.authors),
            'image_url': article['image_url']
        })
    except Exception as e:
        print(f"Error scraping {article['link']}: {e}")
# Out:
# Processing 1/6: Nifty 50, Sensex: Mr Perma Bull takes some market ...
# Processing 2/6: Business cycle funds: Hit or miss?...
# Processing 3/6: Business News | Bajaj Finserv Banking and Financia...
# Processing 4/6: Bajaj Finserv Banking and Financial Services Fund ...
# Processing 5/6: Editorial: Big banks, bigger questions...
# Processing 6/6: Bajaj Finserv Banking and Financial Services Fund ...

# %%
import pandas as pd
import os
import urllib.parse

from newspaper import Article
from newsdataapi import NewsDataApiClient

# %%
def newsdata_connect():
    try:
        api = NewsDataApiClient(apikey='pub_965468a202be412d80928d294b632639')
        print('connected to API')
        return api
    except Exception as e:
        print("Not connected to API")
        return None
    

def extract_news(query, limit:int=5, country:str='in'):
    api = newsdata_connect()
    # step 1: get articles from API
    # if query==None:
    #     query = 'stock market India economy finance NSE BSE'
    # # query = query.strip()
    # print(f"Using query: '{query}'")
    # print(type(query))

    try:
        response = api.latest_api(
            q=query,
            country=country,
            category='top',
            size=limit,
            language='en'
        )
        articles = response.get('results',[])
        print('reached here')
        print(articles)
    except Exception as e:
        print("No articles returned")
        return []

    # step 2: scrape full content from each URL
    full_articles = []
    for idx, article in enumerate(articles, 1):
        print(idx)
        try:
            print(f"Processing {idx}/{len(articles)}: {article['title'][:50]}...")
            url = article.get('link') # article['link']
            if not url:
                print("Skipping: No url")
                continue
            # get full content
            news_article = Article(url)
            news_article.download()
            news_article.parse()
            full_articles.append({
                'article_id': article['article_id'],
                'title': article['title'],
                'description': article['description'],
                'source': article['source_name'],
                'url': article['link'],
                'pubDate': article['pubDate'],
                'category': article['category'],
                'full_content': news_article.text,
                'authors': ', '.join(news_article.authors),
                'image_url': article['image_url']
            })
        except Exception as e:
            print(f"Error scraping {article['link']}: {e}")
    return full_articles

def save_newsdata(full_articles, data_dir):
    os.makedirs(data_dir, exist_ok=True)
    filepath = os.path.join(data_dir, 'news_articles.parquet')
    if os.path.exists(filepath):
        os.remove(filepath)
    full_articles.to_parquet(filepath, compression='brotli')

# %%
# List of multiple phrases
queries = ["Hospital", "Nifty 50", "Tata Motors"]

# Combine queries into a single OR-separated string with quotes
combined_query = " OR ".join([f'"{q}"' for q in queries])
# query = query.strip()
full_articles = extract_news(query=combined_query, limit=5)
# Out:
# connected to API
# reached here
# [{'article_id': '42c00821355d99693a3cb31103c106db', 'link': 'https://timesofindia.indiatimes.com/city/bhubaneswar/bmc-plans-commercial-complex-convention-centre-in-chandrasekharpur/articleshow/125257493.cms', 'title': 'BMC plans commercial complex & convention centre in Chandrasekharpur', 'description': None, 'content': 'ONLY AVAILABLE IN PAID PLANS', 'keywords': ['chandrasekharpur convention centre', 'commercial complex in bhubaneswar', 'urban infrastructure development', 'convention centre project', 'bhubaneswar municipal corporation'], 'creator': ['Sandip Mishra'], 'language': 'english', 'country': ['india'], 'category': ['business', 'top'], 'pubDate': '2025-11-11 23:36:53', 'pubDateTZ': 'UTC', 'image_url': 'https://static.toiimg.com/thumb/msid-125257491,width-1070,height-580,imgsize-62048,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg', 'video_url': None, 'source_id': 'toi', 'source_name': 'The Times Of India', 'source_priority': 2178, 'source_url': 'https://timesofindia.indiatimes.com', 'source_icon': 'https://n.bytvi.com/toi.png', 'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS', 'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS', 'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS', 'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS', 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS', 'ai_summary': 'ONLY AVAILABLE IN PAID PLANS', 'duplicate': False}, {'article_id': '031653bc2a63220554cb418f74fefbef', 'link': 'https://www.hindustantimes.com/cities/pune-news/woman-warkari-killed-ten-others-injured-as-container-truck-ploughs-into-group-of-pilgrims-on-mumbai-pune-highway-101762885714285.html', 'title': 'Woman warkari killed, ten others injured as container truck ploughs into group of pilgrims on Mumbai-Pune highway', 'description': 'A speeding truck killed a warkari and injured 10 others near Kamshet on the Pune-Mumbai Highway while they were on a pilgrimage.', 'content': 'ONLY AVAILABLE IN PAID PLANS', 'keywords': ['cities/pune-news'], 'creator': ['Shrinivas Deshpande'], 'language': 'english', 'country': ['india'], 'category': ['top', 'crime'], 'pubDate': '2025-11-11 23:32:04', 'pubDateTZ': 'UTC', 'image_url': 'https://www.hindustantimes.com/ht-img/img/2025/11/11/1600x900/logo/The-Injured-were-immediately-shifted-to-a-nearby-h_1762886550568.jpeg', 'video_url': None, 'source_id': 'hindustantimes', 'source_name': 'Hindustan Times', 'source_priority': 2173, 'source_url': 'http://www.hindustantimes.com', 'source_icon': 'https://n.bytvi.com/hindustantimes.png', 'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS', 'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS', 'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS', 'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS', 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS', 'ai_summary': 'ONLY AVAILABLE IN PAID PLANS', 'duplicate': False}, {'article_id': '7dee2480f42b280ef22838a9a1ae512d', 'link': 'https://www.livemint.com/news/india/india-draws-up-pathogen-playbook-to-fight-the-superbug-11762858805317.html', 'title': 'India draws up pathogen playbook to fight the superbug', 'description': 'To tackle antimicrobial resistance, the ICMR is designing a framework for standardized pathogen testing across India. This initiative aims to improve diagnostic consistency, accelerate accurate treatment, and enhance public health response to infectious diseases.', 'content': 'ONLY AVAILABLE IN PAID PLANS', 'keywords': ['priority pathogens', 'icmr', 'antimicrobial resistance', 'health crisis', 'priority pathogen testing', 'public health crisis', 'infectious disease diagnostics'], 'creator': ['Priyanka Sharma'], 'language': 'english', 'country': ['india'], 'category': ['top'], 'pubDate': '2025-11-11 23:30:04', 'pubDateTZ': 'UTC', 'image_url': 'https://www.livemint.com/lm-img/img/2025/11/11/1600x900/logo/3-0-17104958-istockphoto-1012405368-2048x2048-0_1679826041814_1762872692738.jpg', 'video_url': None, 'source_id ...
# 1
# Processing 1/5: BMC plans commercial complex & convention centre i...
# 2
# Processing 2/5: Woman warkari killed, ten others injured as contai...
# Error scraping https://www.hindustantimes.com/cities/pune-news/woman-warkari-killed-ten-others-injured-as-container-truck-ploughs-into-group-of-pilgrims-on-mumbai-pune-highway-101762885714285.html: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.hindustantimes.com/cities/pune-news/woman-warkari-killed-ten-others-injured-as-container-truck-ploughs-into-group-of-pilgrims-on-mumbai-pune-highway-101762885714285.html on URL https://www.hindustantimes.com/cities/pune-news/woman-warkari-killed-ten-others-injured-as-container-truck-ploughs-into-group-of-pilgrims-on-mumbai-pune-highway-101762885714285.html
# 3
# Processing 3/5: India draws up pathogen playbook to fight the supe...
# 4
# Processing 4/5: Trading Plan: Will Nifty decisively surpass 25,800...
# 5
# Processing 5/5: Indore News: Man Asleep On Cot Bitten By Snake, Di...

# %%
from newspaper import Article

url = 'http://fox13now.com/2013/12/30/new-year-new-laws-obamacare-pot-guns-and-drones/'
article = Article(url)

# %%
article.download()

# %%
article.html
article.parse()

# %%
article.text
# Out:
# 'By Leigh Ann Caldwell\n\nWASHINGTON (CNN) — Not everyone subscribes to a New Year’s resolution, but Americans will be required to follow new laws in 2014.\n\nSome 40,000 measures taking effect range from sweeping, national mandates under Obamacare to marijuana legalization in Colorado, drone prohibition in Illinois and transgender protections in California.\n\nAlthough many new laws are controversial, they made it through legislatures, public referendum or city councils and represent the shifting composition of American beliefs.\n\nFederal: Health care, of course, and vending machines\n\nThe biggest and most politically charged change comes at the federal level with the imposition of a new fee for those adults without health insurance.\n\nFor 2014, the penalty is either $95 per adult or 1% of family income, whichever results in a larger fine.\n\nThe Obamacare, of Affordable Care Act, mandate also requires that insurers cover immunizations and some preventive care.\n\nAdditionally, millions of poor Americans will receive Medicaid benefits starting January 1.\n\nThousands of companies will have to provide calorie counts for products sold in vending machines.\n\nLocal: Guns, family leave and shark fins\n\nConnecticut: While no national legislation was approved to tighten gun laws a year after the Newtown school shooting, Connecticut is implementing a final round of changes to its books: All assault weapons and large capacity magazines must be registered.\n\nOregon: Family leave in Oregon has been expanded to allow eligible employees two weeks of paid leave to handle the death of a family member.\n\nCalifornia: Homeless youth are eligible to receive food stamps. The previous law had a minimum wage requirement.\n\nDelaware: Delaware is the latest in a growing number of states where residents can no longer possess, sell or distribute shark fins, which is considered a delicacy in some East Asian cuisine.\n\nIllinois and drones\n\nIllinois: passed two laws limiting the use of drones. One prohibits them from interfering with hunters and fisherman. The measure passed after the group People for the Ethical Treatment of Animals said it would use drones to monitor hunters. PETA said it aims through its “air angels” effort to protect against “cruel” and “illegal” hunting.\n\nAlso in Illinois, another law prohibits the use of drones for law enforcement without a warrant.\n\nGender and voting identity\n\nCalifornia: Students can use bathrooms and join school athletic teams “consistent with their gender identity,” even if it’s different than their gender at birth.\n\nArkansas: The state becomes the latest state requiring voters show a picture ID at the voting booth.\n\nMinimum wage and former felon employment\n\nWorkers in 13 states and four cities will see increases to the minimum wage.\n\nWhile most amount to less than 15 cents per hour, workers in places like New Jersey, and Connecticut.\n\nNew Jersey residents voted to raise the state’s minimum wage by $1 to $8.25 per hour. And in Connecticut, lawmakers voted to raise it between 25 and 75 cents to $8.70. The wage would go up to $8 in Rhode Island and New York.\n\nCalifornia is also raising its minimum wage to $9 per hour, but workers must wait until July to see the addition.\n\nRhode Island: It is the latest state to prohibit employers from requiring job applicants to signify if they have a criminal record on a job application.\n\nSocial media and pot\n\nOregon: Employers and schools can’t require a job or student applicant to provide passwords to social media accounts.\n\nColorado: Marijuana becomes legal in the state for buyers over 21 at a licensed retail dispensary.\n\n(Sourcing: much of this list was obtained from the National Conference of State Legislatures).'
